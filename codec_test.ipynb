# %%
from Amphion.models.codec.ns3_codec import FACodecEncoder, FACodecDecoder
import torch

fa_encoder = FACodecEncoder(
    ngf=32,
    up_ratios=[2, 4, 5, 5],
    out_channels=256,
)

fa_decoder = FACodecDecoder(
    in_channels=256,
    upsample_initial_channel=1024,
    ngf=32,
    up_ratios=[5, 5, 4, 2],
    vq_num_q_c=2,
    vq_num_q_p=1,
    vq_num_q_r=3,
    vq_dim=256,
    codebook_dim=8,
    codebook_size_prosody=10,
    codebook_size_content=10,
    codebook_size_residual=10,
    use_gr_x_timbre=True,
    use_gr_residual_f0=True,
    use_gr_residual_phone=True,
)

encoder_ckpt = "pre_trained/ns3_facodec_encoder.bin"
decoder_ckpt = "pre_trained/ns3_facodec_decoder.bin"

fa_encoder.load_state_dict(torch.load(encoder_ckpt))
fa_decoder.load_state_dict(torch.load(decoder_ckpt))

fa_encoder.eval()
fa_decoder.eval()
# Out:
# FACodecDecoder(
#   (quantizer): ModuleList(
#     (0): ResidualVQ(
#       (layers): ModuleList(
#         (0): FactorizedVectorQuantize(
#           (in_proj): Linear(in_features=256, out_features=8, bias=True)
#           (out_proj): Linear(in_features=8, out_features=256, bias=True)
#           (_codebook): Embedding(1024, 8)
#         )
#       )
#     )
#     (1): ResidualVQ(
#       (layers): ModuleList(
#         (0-1): 2 x FactorizedVectorQuantize(
#           (in_proj): Linear(in_features=256, out_features=8, bias=True)
#           (out_proj): Linear(in_features=8, out_features=256, bias=True)
#           (_codebook): Embedding(1024, 8)
#         )
#       )
#     )
#     (2): ResidualVQ(
#       (layers): ModuleList(
#         (0-2): 3 x FactorizedVectorQuantize(
#           (in_proj): Linear(in_features=256, out_features=8, bias=True)
#           (out_proj): Linear(in_features=8, out_features=256, bias=True)
#           (_codebook): Embedding(1024, 8)
#         )
#       )
#     )
#   )
#   (model): Sequential(
#     (0): Conv1d(256, 1024, kernel_size=(7,), stride=(1,), padding=(3,))
#     (1): DecoderBlock(
#       (block): Sequential(
#         (0): Activation1d(
#           (act): SnakeBeta()
#           (upsample): UpSample1d()
#           (downsample): DownSample1d(
#             (lowpass): LowPassFilter1d()
#           )
#         )
#         (1): ConvTranspose1d(1024, 512, kernel_size=(10,), stride=(5,), padding=(3,), output_padding=(1,))
#         (2): ResidualUnit(
#           (block): Sequential(
#             (0): Activation1d(
#               (act): SnakeBeta()
#               (upsample): UpSample1d()
#               (downsample): DownSample1d(
#                 (lowpass): LowPassFilter1d()
#               )
#             )
#             (1): Conv1d(512, 512, kernel_size=(7,), stride=(1,), padding=(3,))
#             (2): Activation1d(
#               (act): SnakeBeta()
#               (upsample): UpSample1d()
#               (downsample): DownSample1d(
#                 (lowpass): LowPassFilter1d()
#               )
#             )
#             (3): Conv1d(512, 512, kernel_size=(1,), stride=(1,))
#           )
#         )
#         (3): ResidualUnit(
#           (block): Sequential(
#             (0): Activation1d(
#               (act): SnakeBeta()
#               (upsample): UpSample1d()
#               (downsample): DownSample1d(
#                 (lowpass): LowPassFilter1d()
#               )
#             )
#             (1): Conv1d(512, 512, kernel_size=(7,), stride=(1,), padding=(9,), dilation=(3,))
#             (2): Activation1d(
#               (act): SnakeBeta()
#               (upsample): UpSample1d()
#               (downsample): DownSample1d(
#                 (lowpass): LowPassFilter1d()
#               )
#             )
#             (3): Conv1d(512, 512, kernel_size=(1,), stride=(1,))
#           )
#         )
#         (4): ResidualUnit(
#           (block): Sequential(
#             (0): Activation1d(
#               (act): SnakeBeta()
#               (upsample): UpSample1d()
#               (downsample): DownSample1d(
#                 (lowpass): LowPassFilter1d()
#               )
#             )
#             (1): Conv1d(512, 512, kernel_size=(7,), stride=(1,), padding=(27,), dilation=(9,))
#             (2): Activation1d(
#               (act): SnakeBeta()
#               (upsample): UpSample1d()
#               (downsample): DownSample1d(
#                 (lowpass): LowPassFilter1d()
#               )
#             )
#             (3): Conv1d(512, 512, kernel_size=(1,), stride=(1,))
#           )
#         )
#       )
#     )
#     (2): DecoderBlock(
#       (block): Sequential(
#         (0): Activation1d(
#           (act): SnakeBeta()
#           (upsample): UpSample1d()
#           (downsample): DownSample1d(
#             (lowpass): LowPassFilter1d()
#           )
#         )
#         (1): ConvTranspose1d(512, 256, kernel_size=(10,), stride=(5,), padding=(3,), output_padding=(1,))
#         (2): ResidualUnit(
#           (block): Sequential(
#             (0): Activation1d(
#               (act): SnakeBeta()
#               (upsample): UpSample1d()
#               (downsample): DownSample1d(
#                 (lowpass): LowPassFilter1d()
#               )
#             )
#             (1): Conv1d(256, 256, kernel_size=(7,), stride=(1,), padding=(3,))
#             (2): Activation1d(
#               (act): SnakeBeta()
#               (upsample): UpSample1d()
#               (downsample): DownSample1d(
#                 (lowpass): LowPassFilter1d()
#               )
#             )
#             (3): Conv1d(256, 256, kernel_size=(1,), stride=(1,))
#           )
#         )
#         (3): ResidualUnit(
#           (block): Sequential(
#             (0): Activation1d(
#               (act): SnakeBeta()
#               (upsample): UpSample1d()
#               (downsample): DownSample1d(
#                 (lowpass): LowPassFilter1d()
#               )
#             )
#             (1): Conv1d(256, 256, kernel_size=(7,), stride=(1,), padding=(9,), dilation=(3,))
#             (2): Activation1d(
#               (act): SnakeBeta()
#               (upsample): UpSample1d()
#               (downsample): DownSample1d(
#                 (lowpass): LowPassFilter1d()
#               )
#             )
#             (3): Conv1d(256, 256, kernel_size=(1,), stride=(1,))
#           )
#         )
#         (4): ResidualUnit(
#           (block): Sequential(
#             (0): Activation1d(
#               (act): SnakeBeta()
#               (upsample): UpSample1d()
#               (downsample): DownSample1d(
#                 (lowpass): LowPassFilter1d()
#               )
#             )
#             (1): Conv1d(256, 256, kernel_size=(7,), stride=(1,), padding=(27,), dilation=(9,))
#             (2): Activation1d(
#               (act): SnakeBeta()
#               (upsample): UpSample1d()
#               (downsample): DownSample1d(
#                 (lowpass): LowPassFilter1d()
#               )
#             )
#             (3): Conv1d(256, 256, kernel_size=(1,), stride=(1,))
#           )
#         )
#       )
#     )
#     (3): DecoderBlock(
#       (block): Sequential(
#         (0): Activation1d(
#           (act): SnakeBeta()
#           (upsample): UpSample1d()
#           (downsample): DownSample1d(
#             (lowpass): LowPassFilter1d()
#           )
#         )
#         (1): ConvTranspose1d(256, 128, kernel_size=(8,), stride=(4,), padding=(2,))
#         (2): ResidualUnit(
#           (block): Sequential(
#             (0): Activation1d(
#               (act): SnakeBeta()
#               (upsample): UpSample1d()
#               (downsample): DownSample1d(
#                 (lowpass): LowPassFilter1d()
#               )
#             )
#             (1): Conv1d(128, 128, kernel_size=(7,), stride=(1,), padding=(3,))
#             (2): Activation1d(
#               (act): SnakeBeta()
#               (upsample): UpSample1d()
#               (downsample): DownSample1d(
#                 (lowpass): LowPassFilter1d()
#               )
#             )
#             (3): Conv1d(128, 128, kernel_size=(1,), stride=(1,))
#           )
#         )
#         (3): ResidualUnit(
#           (block): Sequential(
#             (0): Activation1d(
#               (act): SnakeBeta()
#               (upsample): UpSample1d()
#               (downsample): DownSample1d(
#                 (lowpass): LowPassFilter1d()
#               )
#             )
#             (1): Conv1d(128, 128, kernel_size=(7,), stride=(1,), padding=(9,), dilation=(3,))
#             (2): Activation1d(
#               (act): SnakeBeta()
#               (upsample): UpSample1d()
#               (downsample): DownSample1d(
#                 (lowpass): LowPassFilter1d()
#               )
#             )
#             (3): Conv1d(128, 128, kernel_size=(1,), stride=(1,))
#           )
#         )
#         (4): ResidualUnit(
#           (block): Sequential(
#             (0): Activation1d(
#               (act): SnakeBeta()
#               (upsample): UpSample1d()
#               (downsample): DownSample1d(
#                 (lowpass): LowPassFilter1d()
#               )
#             )
#             (1): Conv1d(128, 128, kernel_size=(7,), stride=(1,), padding=(27,), dilation=(9,))
#             (2): Activation1d(
#               (act): SnakeBeta()
#               (upsample): UpSample1d()
#               (downsample): DownSample1d(
#                 (lowpass): LowPassFilter1d()
#               )
#             )
#             (3): Conv1d(128, 128, kernel_size=(1,), stride=(1,))
#           )
#         )
#       )
#     )
#     (4): DecoderBlock(
#       (block): Sequential(
#         (0): Activation1d(
#           (act): SnakeBeta()
#           (upsample): UpSample1d()
#           (downsample): DownSample1d(
#             (lowpass): LowPassFilter1d()
#           )
#         )
#         (1): ConvTranspose1d(128, 64, kernel_size=(4,), stride=(2,), padding=(1,))
#         (2): ResidualUnit(
#           (block): Sequential(
#             (0): Activation1d(
#               (act): SnakeBeta()
#               (upsample): UpSample1d()
#               (downsample): DownSample1d(
#                 (lowpass): LowPassFilter1d()
#               )
#             )
#             (1): Conv1d(64, 64, kernel_size=(7,), stride=(1,), padding=(3,))
#             (2): Activation1d(
#               (act): SnakeBeta()
#               (upsample): UpSample1d()
#               (downsample): DownSample1d(
#                 (lowpass): LowPassFilter1d()
#               )
#             )
#             (3): Conv1d(64, 64, kernel_size=(1,), stride=(1,))
#           )
#         )
#         (3): ResidualUnit(
#           (block): Sequential(
#             (0): Activation1d(
#               (act): SnakeBeta()
#               (upsample): UpSample1d()
#               (downsample): DownSample1d(
#                 (lowpass): LowPassFilter1d()
#               )
#             )
#             (1): Conv1d(64, 64, kernel_size=(7,), stride=(1,), padding=(9,), dilation=(3,))
#             (2): Activation1d(
#               (act): SnakeBeta()
#               (upsample): UpSample1d()
#               (downsample): DownSample1d(
#                 (lowpass): LowPassFilter1d()
#               )
#             )
#             (3): Conv1d(64, 64, kernel_size=(1,), stride=(1,))
#           )
#         )
#         (4): ResidualUnit(
#           (block): Sequential(
#             (0): Activation1d(
#               (act): SnakeBeta()
#               (upsample): UpSample1d()
#               (downsample): DownSample1d(
#                 (lowpass): LowPassFilter1d()
#               )
#             )
#             (1): Conv1d(64, 64, kernel_size=(7,), stride=(1,), padding=(27,), dilation=(9,))
#             (2): Activation1d(
#               (act): SnakeBeta()
#               (upsample): UpSample1d()
#               (downsample): DownSample1d(
#                 (lowpass): LowPassFilter1d()
#               )
#             )
#             (3): Conv1d(64, 64, kernel_size=(1,), stride=(1,))
#           )
#         )
#       )
#     )
#     (5): Activation1d(
#       (act): SnakeBeta()
#       (upsample): UpSample1d()
#       (downsample): DownSample1d(
#         (lowpass): LowPassFilter1d()
#       )
#     )
#     (6): Conv1d(64, 1, kernel_size=(7,), stride=(1,), padding=(3,))
#     (7): Tanh()
#   )
#   (timbre_encoder): TransformerEncoder(
#     (position_emb): PositionalEncoding()
#     (layers): ModuleList(
#       (0-3): 4 x TransformerEncoderLayer(
#         (ln_1): LayerNorm((256,), eps=1e-05, elementwise_affine=True)
#         (ln_2): LayerNorm((256,), eps=1e-05, elementwise_affine=True)
#         (self_attn): MultiheadAttention(
#           (out_proj): NonDynamicallyQuantizableLinear(in_features=256, out_features=256, bias=True)
#         )
#         (ffn): TransformerFFNLayer(
#           (ffn_1): Conv1d(256, 1024, kernel_size=(5,), stride=(1,), padding=(2,))
#           (ffn_2): Linear(in_features=1024, out_features=256, bias=True)
#         )
#       )
#     )
#     (last_ln): LayerNorm((256,), eps=1e-05, elementwise_affine=True)
#   )
#   (timbre_linear): Linear(in_features=256, out_features=512, bias=True)
#   (timbre_norm): LayerNorm((256,), eps=1e-05, elementwise_affine=False)
#   (f0_predictor): CNNLSTM(
#     (model): Sequential(
#       (0): ResidualUnit(
#         (block): Sequential(
#           (0): Activation1d(
#             (act): SnakeBeta()
#             (upsample): UpSample1d()
#             (downsample): DownSample1d(
#               (lowpass): LowPassFilter1d()
#             )
#           )
#           (1): Conv1d(256, 256, kernel_size=(7,), stride=(1,), padding=(3,))
#           (2): Activation1d(
#             (act): SnakeBeta()
#             (upsample): UpSample1d()
#             (downsample): DownSample1d(
#               (lowpass): LowPassFilter1d()
#             )
#           )
#           (3): Conv1d(256, 256, kernel_size=(1,), stride=(1,))
#         )
#       )
#       (1): ResidualUnit(
#         (block): Sequential(
#           (0): Activation1d(
#             (act): SnakeBeta()
#             (upsample): UpSample1d()
#             (downsample): DownSample1d(
#               (lowpass): LowPassFilter1d()
#             )
#           )
#           (1): Conv1d(256, 256, kernel_size=(7,), stride=(1,), padding=(6,), dilation=(2,))
#           (2): Activation1d(
#             (act): SnakeBeta()
#             (upsample): UpSample1d()
#             (downsample): DownSample1d(
#               (lowpass): LowPassFilter1d()
#             )
#           )
#           (3): Conv1d(256, 256, kernel_size=(1,), stride=(1,))
#         )
#       )
#       (2): ResidualUnit(
#         (block): Sequential(
#           (0): Activation1d(
#             (act): SnakeBeta()
#             (upsample): UpSample1d()
#             (downsample): DownSample1d(
#               (lowpass): LowPassFilter1d()
#             )
#           )
#           (1): Conv1d(256, 256, kernel_size=(7,), stride=(1,), padding=(9,), dilation=(3,))
#           (2): Activation1d(
#             (act): SnakeBeta()
#             (upsample): UpSample1d()
#             (downsample): DownSample1d(
#               (lowpass): LowPassFilter1d()
#             )
#           )
#           (3): Conv1d(256, 256, kernel_size=(1,), stride=(1,))
#         )
#       )
#       (3): Activation1d(
#         (act): SnakeBeta()
#         (upsample): UpSample1d()
#         (downsample): DownSample1d(
#           (lowpass): LowPassFilter1d()
#         )
#       )
#       (4): Rearrange('b c t -> b t c')
#     )
#     (heads): ModuleList(
#       (0-1): 2 x Linear(in_features=256, out_features=1, bias=True)
#     )
#   )
#   (phone_predictor): CNNLSTM(
#     (model): Sequential(
#       (0): ResidualUnit(
#         (block): Sequential(
#           (0): Activation1d(
#             (act): SnakeBeta()
#             (upsample): UpSample1d()
#             (downsample): DownSample1d(
#               (lowpass): LowPassFilter1d()
#             )
#           )
#           (1): Conv1d(256, 256, kernel_size=(7,), stride=(1,), padding=(3,))
#           (2): Activation1d(
#             (act): SnakeBeta()
#             (upsample): UpSample1d()
#             (downsample): DownSample1d(
#               (lowpass): LowPassFilter1d()
#             )
#           )
#           (3): Conv1d(256, 256, kernel_size=(1,), stride=(1,))
#         )
#       )
#       (1): ResidualUnit(
#         (block): Sequential(
#           (0): Activation1d(
#             (act): SnakeBeta()
#             (upsample): UpSample1d()
#             (downsample): DownSample1d(
#               (lowpass): LowPassFilter1d()
#             )
#           )
#           (1): Conv1d(256, 256, kernel_size=(7,), stride=(1,), padding=(6,), dilation=(2,))
#           (2): Activation1d(
#             (act): SnakeBeta()
#             (upsample): UpSample1d()
#             (downsample): DownSample1d(
#               (lowpass): LowPassFilter1d()
#             )
#           )
#           (3): Conv1d(256, 256, kernel_size=(1,), stride=(1,))
#         )
#       )
#       (2): ResidualUnit(
#         (block): Sequential(
#           (0): Activation1d(
#             (act): SnakeBeta()
#             (upsample): UpSample1d()
#             (downsample): DownSample1d(
#               (lowpass): LowPassFilter1d()
#             )
#           )
#           (1): Conv1d(256, 256, kernel_size=(7,), stride=(1,), padding=(9,), dilation=(3,))
#           (2): Activation1d(
#             (act): SnakeBeta()
#             (upsample): UpSample1d()
#             (downsample): DownSample1d(
#               (lowpass): LowPassFilter1d()
#             )
#           )
#           (3): Conv1d(256, 256, kernel_size=(1,), stride=(1,))
#         )
#       )
#       (3): Activation1d(
#         (act): SnakeBeta()
#         (upsample): UpSample1d()
#         (downsample): DownSample1d(
#           (lowpass): LowPassFilter1d()
#         )
#       )
#       (4): Rearrange('b c t -> b t c')
#     )
#     (heads): ModuleList(
#       (0): Linear(in_features=256, out_features=5003, bias=True)
#     )
#   )
#   (res_f0_predictor): Sequential(
#     (0): GradientReversal()
#     (1): CNNLSTM(
#       (model): Sequential(
#         (0): ResidualUnit(
#           (block): Sequential(
#             (0): Activation1d(
#               (act): SnakeBeta()
#               (upsample): UpSample1d()
#               (downsample): DownSample1d(
#                 (lowpass): LowPassFilter1d()
#               )
#             )
#             (1): Conv1d(256, 256, kernel_size=(7,), stride=(1,), padding=(3,))
#             (2): Activation1d(
#               (act): SnakeBeta()
#               (upsample): UpSample1d()
#               (downsample): DownSample1d(
#                 (lowpass): LowPassFilter1d()
#               )
#             )
#             (3): Conv1d(256, 256, kernel_size=(1,), stride=(1,))
#           )
#         )
#         (1): ResidualUnit(
#           (block): Sequential(
#             (0): Activation1d(
#               (act): SnakeBeta()
#               (upsample): UpSample1d()
#               (downsample): DownSample1d(
#                 (lowpass): LowPassFilter1d()
#               )
#             )
#             (1): Conv1d(256, 256, kernel_size=(7,), stride=(1,), padding=(6,), dilation=(2,))
#             (2): Activation1d(
#               (act): SnakeBeta()
#               (upsample): UpSample1d()
#               (downsample): DownSample1d(
#                 (lowpass): LowPassFilter1d()
#               )
#             )
#             (3): Conv1d(256, 256, kernel_size=(1,), stride=(1,))
#           )
#         )
#         (2): ResidualUnit(
#           (block): Sequential(
#             (0): Activation1d(
#               (act): SnakeBeta()
#               (upsample): UpSample1d()
#               (downsample): DownSample1d(
#                 (lowpass): LowPassFilter1d()
#               )
#             )
#             (1): Conv1d(256, 256, kernel_size=(7,), stride=(1,), padding=(9,), dilation=(3,))
#             (2): Activation1d(
#               (act): SnakeBeta()
#               (upsample): UpSample1d()
#               (downsample): DownSample1d(
#                 (lowpass): LowPassFilter1d()
#               )
#             )
#             (3): Conv1d(256, 256, kernel_size=(1,), stride=(1,))
#           )
#         )
#         (3): Activation1d(
#           (act): SnakeBeta()
#           (upsample): UpSample1d()
#           (downsample): DownSample1d(
#             (lowpass): LowPassFilter1d()
#           )
#         )
#         (4): Rearrange('b c t -> b t c')
#       )
#       (heads): ModuleList(
#         (0-1): 2 x Linear(in_features=256, out_features=1, bias=True)
#       )
#     )
#   )
#   (res_phone_predictor): Sequential(
#     (0): GradientReversal()
#     (1): CNNLSTM(
#       (model): Sequential(
#         (0): ResidualUnit(
#           (block): Sequential(
#             (0): Activation1d(
#               (act): SnakeBeta()
#               (upsample): UpSample1d()
#               (downsample): DownSample1d(
#                 (lowpass): LowPassFilter1d()
#               )
#             )
#             (1): Conv1d(256, 256, kernel_size=(7,), stride=(1,), padding=(3,))
#             (2): Activation1d(
#               (act): SnakeBeta()
#               (upsample): UpSample1d()
#               (downsample): DownSample1d(
#                 (lowpass): LowPassFilter1d()
#               )
#             )
#             (3): Conv1d(256, 256, kernel_size=(1,), stride=(1,))
#           )
#         )
#         (1): ResidualUnit(
#           (block): Sequential(
#             (0): Activation1d(
#               (act): SnakeBeta()
#               (upsample): UpSample1d()
#               (downsample): DownSample1d(
#                 (lowpass): LowPassFilter1d()
#               )
#             )
#             (1): Conv1d(256, 256, kernel_size=(7,), stride=(1,), padding=(6,), dilation=(2,))
#             (2): Activation1d(
#               (act): SnakeBeta()
#               (upsample): UpSample1d()
#               (downsample): DownSample1d(
#                 (lowpass): LowPassFilter1d()
#               )
#             )
#             (3): Conv1d(256, 256, kernel_size=(1,), stride=(1,))
#           )
#         )
#         (2): ResidualUnit(
#           (block): Sequential(
#             (0): Activation1d(
#               (act): SnakeBeta()
#               (upsample): UpSample1d()
#               (downsample): DownSample1d(
#                 (lowpass): LowPassFilter1d()
#               )
#             )
#             (1): Conv1d(256, 256, kernel_size=(7,), stride=(1,), padding=(9,), dilation=(3,))
#             (2): Activation1d(
#               (act): SnakeBeta()
#               (upsample): UpSample1d()
#               (downsample): DownSample1d(
#                 (lowpass): LowPassFilter1d()
#               )
#             )
#             (3): Conv1d(256, 256, kernel_size=(1,), stride=(1,))
#           )
#         )
#         (3): Activation1d(
#           (act): SnakeBeta()
#           (upsample): UpSample1d()
#           (downsample): DownSample1d(
#             (lowpass): LowPassFilter1d()
#           )
#         )
#         (4): Rearrange('b c t -> b t c')
#       )
#       (heads): ModuleList(
#         (0): Linear(in_features=256, out_features=5003, bias=True)
#       )
#     )
#   )
#   (x_timbre_predictor): Sequential(
#     (0): GradientReversal()
#     (1): CNNLSTM(
#       (model): Sequential(
#         (0): ResidualUnit(
#           (block): Sequential(
#             (0): Activation1d(
#               (act): SnakeBeta()
#               (upsample): UpSample1d()
#               (downsample): DownSample1d(
#                 (lowpass): LowPassFilter1d()
#               )
#             )
#             (1): Conv1d(256, 256, kernel_size=(7,), stride=(1,), padding=(3,))
#             (2): Activation1d(
#               (act): SnakeBeta()
#               (upsample): UpSample1d()
#               (downsample): DownSample1d(
#                 (lowpass): LowPassFilter1d()
#               )
#             )
#             (3): Conv1d(256, 256, kernel_size=(1,), stride=(1,))
#           )
#         )
#         (1): ResidualUnit(
#           (block): Sequential(
#             (0): Activation1d(
#               (act): SnakeBeta()
#               (upsample): UpSample1d()
#               (downsample): DownSample1d(
#                 (lowpass): LowPassFilter1d()
#               )
#             )
#             (1): Conv1d(256, 256, kernel_size=(7,), stride=(1,), padding=(6,), dilation=(2,))
#             (2): Activation1d(
#               (act): SnakeBeta()
#               (upsample): UpSample1d()
#               (downsample): DownSample1d(
#                 (lowpass): LowPassFilter1d()
#               )
#             )
#             (3): Conv1d(256, 256, kernel_size=(1,), stride=(1,))
#           )
#         )
#         (2): ResidualUnit(
#           (block): Sequential(
#             (0): Activation1d(
#               (act): SnakeBeta()
#               (upsample): UpSample1d()
#               (downsample): DownSample1d(
#                 (lowpass): LowPassFilter1d()
#               )
#             )
#             (1): Conv1d(256, 256, kernel_size=(7,), stride=(1,), padding=(9,), dilation=(3,))
#             (2): Activation1d(
#               (act): SnakeBeta()
#               (upsample): UpSample1d()
#               (downsample): DownSample1d(
#                 (lowpass): LowPassFilter1d()
#               )
#             )
#             (3): Conv1d(256, 256, kernel_size=(1,), stride=(1,))
#           )
#         )
#         (3): Activation1d(
#           (act): SnakeBeta()
#           (upsample): UpSample1d()
#           (downsample): DownSample1d(
#             (lowpass): LowPassFilter1d()
#           )
#         )
#         (4): Rearrange('b c t -> b t c')
#       )
#       (heads): ModuleList(
#         (0): Linear(in_features=256, out_features=245200, bias=True)
#       )
#     )
#   )
# )

# %%
import librosa
import soundfile as sf

# %%
test_wav_path = "recordings//afrikaans1.mp3"
test_wav = librosa.load(test_wav_path, sr=16000)[0]
test_wav = torch.from_numpy(test_wav).float()
test_wav = test_wav.unsqueeze(0).unsqueeze(0)

with torch.no_grad():

    # encode
    enc_out = fa_encoder(test_wav)
    print(enc_out.shape)

    # quantize
    vq_post_emb, vq_id, _, quantized, spk_embs = fa_decoder(enc_out, eval_vq=False, vq=True)
    
    # latent after quantization
    print(vq_post_emb.shape)
    
    # codes
    print("vq id shape:", vq_id.shape)
    
    # get prosody code
    prosody_code = vq_id[:1]
    print("prosody code shape:", prosody_code.shape)
    
    # get content code
    cotent_code = vq_id[1:3]
    print("content code shape:", cotent_code.shape)
    
    # get residual code (acoustic detail codes)
    residual_code = vq_id[3:]
    print("residual code shape:", residual_code.shape)
    
    # speaker embedding
    print("speaker embedding shape:", spk_embs.shape)

    # decode (recommand)
    recon_wav = fa_decoder.inference(vq_post_emb, spk_embs)
    print(recon_wav.shape)
    sf.write("recon.wav", recon_wav[0][0].cpu().numpy(), 16000)
# Out:
# torch.Size([1, 256, 1662])
# torch.Size([1, 256, 1662])
# vq id shape: torch.Size([6, 1, 1662])
# prosody code shape: torch.Size([1, 1, 1662])
# content code shape: torch.Size([2, 1, 1662])
# residual code shape: torch.Size([3, 1, 1662])
# speaker embedding shape: torch.Size([1, 256])
# torch.Size([1, 1, 332400])

# %%
wav_a = "recordings/japanese12.mp3"
wav_a = librosa.load(wav_a, sr=16000)[0]
wav_a = torch.from_numpy(wav_a).float()
wav_a = wav_a.unsqueeze(0).unsqueeze(0)

wav_b = "recordings/afrikaans1.mp3"
wav_b = librosa.load(wav_b, sr=16000)[0]
wav_b = torch.from_numpy(wav_b).float()
wav_b = wav_b.unsqueeze(0).unsqueeze(0)

wav_c = "recordings/albanian3.mp3"
wav_c = librosa.load(wav_c, sr=16000)[0]
wav_c = torch.from_numpy(wav_c).float()
wav_c = wav_c.unsqueeze(0).unsqueeze(0)

# %%
from Amphion.models.codec.ns3_codec import FACodecRedecoder

fa_redecoder = FACodecRedecoder()

redecoder_ckpt = "pre_trained/ns3_facodec_redecoder.bin"

fa_redecoder.load_state_dict(torch.load(redecoder_ckpt))

with torch.no_grad():
    enc_out_a = fa_encoder(wav_a)
    enc_out_b = fa_encoder(wav_b)
    enc_out_c = fa_encoder(wav_c)

    vq_post_emb_a, vq_id_a, _, quantized_a, spk_embs_a = fa_decoder(enc_out_a, eval_vq=False, vq=True)
    vq_post_emb_b, vq_id_b, _, quantized_b, spk_embs_b = fa_decoder(enc_out_b, eval_vq=False, vq=True)
    vq_post_emb_c, vq_id_c, _, quantized_c, spk_embs_c = fa_decoder(enc_out_c, eval_vq=False, vq=True)

    # convert speaker
    import numpy as np
    print("a", np.linalg.norm(spk_embs_a))
    print("b", np.linalg.norm(spk_embs_b))
    print("c", np.linalg.norm(spk_embs_c))
    print("========")
    print("a-b", np.linalg.norm(0.5*(spk_embs_a+spk_embs_b)))
    print("b-c", np.linalg.norm(0.5*(spk_embs_b+spk_embs_c)))
    print("a-c", np.linalg.norm(0.5*(spk_embs_a+spk_embs_c)))
    vq_post_emb_a_to_b = fa_redecoder.vq2emb(vq_id_a, 0.5*(spk_embs_a+spk_embs_b), use_residual=False)
    recon_wav_a_to_b = fa_redecoder.inference(vq_post_emb_a_to_b, 0.5*(spk_embs_a+spk_embs_b))
    sf.write("recon_mix_0.wav", recon_wav_a_to_b[0][0].cpu().numpy(), 16000)

    vq_post_emb_a_to_b = fa_redecoder.vq2emb(vq_id_a, 0.5*(spk_embs_c+spk_embs_b), use_residual=False)
    recon_wav_a_to_b = fa_redecoder.inference(vq_post_emb_a_to_b, 0.5*(spk_embs_c+spk_embs_b))
    sf.write("recon_mix_1.wav", recon_wav_a_to_b[0][0].cpu().numpy(), 16000)

    vq_post_emb_a_to_b = fa_redecoder.vq2emb(vq_id_a, 0.5*(spk_embs_a+spk_embs_c), use_residual=False)
    recon_wav_a_to_b = fa_redecoder.inference(vq_post_emb_a_to_b, 0.5*(spk_embs_a+spk_embs_c))
    sf.write("recon_mix_2.wav", recon_wav_a_to_b[0][0].cpu().numpy(), 16000)
# Out:
# a 4.6099305
# b 4.61502
# c 4.6312647
# ========
# a-b tensor([[-2.9740e-02, -4.1889e-02,  4.6665e-02,  1.1185e-02, -3.3905e-03,
#           2.6135e-02,  8.3394e-03, -1.2767e-02,  1.5883e-02,  4.4698e-02,
#          -8.2097e-02, -1.1117e-01, -2.2878e-02,  1.3188e-02, -5.4757e-02,
#          -7.1202e-02, -5.1012e-02,  1.2391e-02, -5.9583e-02, -6.2296e-02,
#           7.0550e-02, -2.9883e-02,  8.5506e-03,  9.0103e-02, -1.7014e-01,
#          -5.2118e-02,  2.8445e-02,  5.9354e-02,  8.4130e-02, -5.7961e-02,
#           4.1223e-02,  2.5807e-02,  1.6551e-02,  1.1494e-02,  1.4469e-02,
#          -7.8633e-02, -2.1798e-02, -3.2687e-02,  6.2329e-02, -2.2057e-02,
#          -7.3358e-02,  1.0057e-01,  2.4521e-02,  1.4519e-01, -8.5477e-03,
#           1.2722e-01,  3.7495e-02,  2.2706e-02,  3.6226e-02,  5.4672e-02,
#          -4.0516e-02, -4.8729e-02,  1.9640e-02,  2.7480e-01, -6.1631e-02,
#          -6.0146e-03,  8.0231e-02, -5.4857e-02, -9.1438e-03,  7.1098e-02,
#          -8.9541e-02, -2.7011e-03,  1.7345e-02,  6.7650e-02,  4.9921e-02,
#          -5.0450e-02, -5.4352e-01,  1.4945e-02,  4.8618e-02,  5.0244e-02,
#           2.6713e-02,  2.3166e-05,  8.5204e-03, -5.7261e-02, -1.0074e-02,
#           3.0795e-02,  4.0883e-02, -3.8741e-03,  2.2235e-02, -6.3830e-02,
#           2.8854e-02, -6.5459e-02, -1.3157e-02, -2.2731e-02,  3.1260e-02,
#           3.7551e-02,  1.0769e-02,  4.6397e-02, -6.2226e-03, -4.9564e-02,
#           2.1198e-02, -1.0692e-01, -2.6007e-01,  2.6286e-02, -3.0343e-02,
#           3.7590e-02,  5.7773e-03,  1.0741e-01, -1.3861e-01, -4.0580e-03,
#           2.4589e-02, -1.3709e-02,  3.5111e-02,  1.5583e-02, -6.5288e-02,
#           2.2215e-02, -3.7924e-03, -8.8156e-02,  5.9589e-02, -8.7360e-02,
#          -6.1111e-02, -6.9173e-02, -5.5992e-02,  9.7253e-02, -1.3067e-01,
#           3.7287e-02,  5.2751e-02, -2.8024e-02, -7.9632e-03,  4.0672e-02,
#           8.9801e-02, -7.8721e-05,  1.5318e-02,  5.6831e-02,  2.0233e-02,
#          -4.1855e-02,  3.7480e-02, -9.0523e-02, -3.1978e-02, -3.5843e-02,
#          -4.0628e-02, -5.1106e-02, -7.4675e-02, -9.4225e-06, -9.1102e-01,
#           5.8791e-02,  1.4677e-01,  8.8300e-02,  6.4447e-02, -1.6972e-03,
#           4.9425e-02, -8.8171e-02,  1.5773e-03, -7.4439e-02, -1.1600e-02,
#          -3.5185e-02, -3.6282e-03,  2.3803e-02, -3.3923e-02,  1.3513e-01,
#           2.6712e-02, -1.0154e-01, -8.7871e-02,  6.9119e-02, -5.2562e-02,
#           2.0007e-02,  4.0442e-01, -2.6771e-02, -7.8000e-02, -3.6633e-02,
#           3.4123e-02,  1.5448e-02, -7.3499e-02, -9.5834e-02, -4.7715e-02,
#          -4.7596e-02, -6.6592e-02, -3.7194e-02, -7.6468e-03,  4.5107e-02,
#           7.4737e-03,  8.1995e-03, -4.7930e-02, -4.8393e-02,  2.5023e-02,
#           2.4077e-02,  1.0527e-01,  1.0959e-01, -2.5513e-02,  4.2264e-02,
#           6.4701e-02, -5.3938e-02,  1.0799e-02,  3.0609e-02,  9.6156e-03,
#           3.8716e-02, -6.8238e-02,  1.1371e-01, -4.7362e-02, -1.6117e-02,
#           1.1415e-02,  1.7832e-01, -4.1562e-02,  1.6171e-01,  5.0401e-02,
#          -1.2844e-02, -1.3464e-02, -3.9506e-02,  2.4744e-02,  3.0375e-03,
#          -3.3223e-02,  1.4177e-02, -5.2493e-02, -5.5370e-02,  1.4554e-02,
#           5.7192e-02, -1.1197e+00,  7.2931e-02,  5.6106e-02, -8.2415e-02,
#          -1.9479e+00,  5.3665e-02,  4.7506e-03,  7.7414e-02, -2.3744e-02,
#          -8.8469e-03, -6.5262e-02, -2.0322e-02,  1.0981e-01,  7.0302e-02,
#          -1.3391e-02,  3.4818e-02, -1.1473e-01, -1.8017e-02,  3.5187e-02,
#           6.4955e-03,  4.6352e-02, -1.0742e-01, -9.6830e-03, -4.1699e-02,
#           7.0411e-02, -4.0059e-02,  3.8511e-02,  2.5046e-02,  2.5966e-02,
#           2.8644e-02, -9.8324e-02, -5.4299e-02,  7.3697e-02, -2.6329e-02,
#          -9.8197e-02,  5.1369e-02,  3.8050e-02, -5.6594e-02, -8.3481e-02,
#          -6.0450e-02,  3.0731e-02, -5.1306e-02,  6.5881e-02, -4.5431e-02,
#           2.3419e-02,  3.6926e+00,  1.2076e-01,  3.9792e-02,  8.4873e-02,
#          -7.9386e-02]])
# b-c tensor([[-1.2879e-02, -1.5714e-02, -1.1158e-02, -3.9820e-03, -1.7784e-02,
#          -5.0299e-02,  3.7224e-02, -4.6886e-02,  8.8053e-03,  1.2724e-01,
#          -9.0775e-02, -9.2710e-02,  8.8713e-04, -4.1872e-02, -1.3366e-02,
#           5.4661e-02, -1.6016e-02,  7.3633e-04, -2.6418e-02,  2.3155e-02,
#           4.0573e-02, -2.9687e-02,  4.4026e-02,  1.1881e-01, -9.8155e-02,
#           1.1608e-02, -4.2967e-02,  4.8516e-02,  3.1294e-02, -8.7094e-02,
#           1.0167e-01, -2.2888e-02, -4.6596e-02,  6.2136e-02,  2.1001e-02,
#           2.6405e-02, -1.3033e-02, -4.2503e-02,  5.2315e-02, -3.4896e-02,
#          -1.1198e-01,  1.2364e-01, -2.1397e-02,  1.3404e-01,  1.1586e-02,
#           2.2999e-02,  6.6392e-02,  1.9864e-02,  4.2499e-02,  2.4480e-02,
#          -5.1463e-02,  5.5239e-03,  7.7972e-03,  2.5494e-01, -2.7219e-02,
#           2.1691e-02,  6.0335e-03, -7.7375e-02,  1.1945e-02,  2.5980e-02,
#           3.5954e-02, -1.7354e-02,  1.2748e-02,  9.7188e-03,  4.1253e-02,
#          -1.9149e-02, -4.0722e-01,  7.5324e-03, -1.0115e-02,  9.0592e-02,
#           4.1085e-02,  1.9438e-03, -2.7994e-02, -4.8068e-02, -9.5946e-02,
#           8.5472e-03,  6.2836e-02, -4.2869e-02,  8.8976e-03, -7.9015e-02,
#           2.2397e-02, -5.2199e-03,  7.9890e-02,  1.1037e-02, -2.3937e-02,
#          -1.3164e-02, -9.5698e-03,  3.2484e-03, -3.3840e-02, -5.8289e-02,
#           3.4571e-02, -1.1385e-01, -6.7424e-02, -7.7763e-03, -5.0407e-02,
#           1.4277e-01, -5.8573e-03,  5.0986e-02, -1.1976e-01,  2.7453e-02,
#           3.6221e-02,  2.8631e-02,  4.4750e-02,  8.5438e-02, -1.9150e-02,
#          -1.7005e-04,  4.8358e-02, -6.0188e-02,  2.8058e-02, -5.4925e-02,
#          -4.8518e-02, -1.7369e-02, -4.5715e-02,  4.2468e-02, -9.0846e-02,
#           7.1708e-02,  4.9930e-02, -3.2444e-02, -2.2588e-02,  2.7502e-02,
#           8.7342e-02, -2.5935e-02, -5.2213e-02,  1.9272e-02,  6.4759e-02,
#          -1.2462e-01,  4.2836e-02, -3.1765e-02, -6.2097e-02, -6.1007e-02,
#          -2.4813e-02, -5.1714e-02, -5.5747e-02, -5.8664e-02, -8.9582e-01,
#           1.7408e-02,  6.7512e-02,  5.4786e-02,  1.3667e-02, -1.2461e-02,
#           8.5191e-02, -1.6689e-01, -1.3276e-01, -1.4477e-02, -3.5241e-02,
#          -6.2420e-02, -4.9329e-02,  2.6890e-02, -7.0804e-03,  1.5839e-01,
#           4.8139e-02, -6.5377e-02, -2.5252e-02,  8.6452e-03, -4.7196e-02,
#           1.0273e-02,  6.7577e-02, -7.5455e-02, -1.2151e-01,  2.1993e-02,
#           8.3188e-02,  2.8835e-02, -3.0012e-02, -7.8439e-02, -7.7527e-02,
#          -1.9595e-02, -9.1180e-02, -6.9523e-03,  6.7222e-02,  5.6103e-02,
#           2.3897e-03, -7.3639e-02,  1.1970e-03, -6.4514e-02,  1.3377e-02,
#           5.9724e-02,  5.8735e-02,  8.1843e-02, -2.7667e-02,  5.0515e-02,
#           2.7180e-02, -5.4303e-02,  4.2053e-02,  3.8124e-02, -3.2619e-04,
#           1.3037e-02, -2.9128e-02,  1.3419e-01, -3.1954e-02, -5.4985e-02,
#           1.9793e-02,  1.0605e-01, -2.5049e-02,  3.0215e-02,  8.2055e-02,
#          -4.3593e-02,  4.3928e-02, -3.3479e-03, -6.8880e-03,  7.9017e-03,
#          -9.5287e-03,  3.0975e-03, -8.7028e-03, -1.4748e-02,  3.2421e-02,
#           5.0210e-02, -1.0253e+00,  1.9005e-02, -1.6436e-02, -5.8709e-02,
#          -1.9657e+00,  2.1346e-02,  1.0327e-02,  1.8791e-02, -3.6261e-03,
#          -7.5493e-03, -2.0684e-02, -1.6772e-02,  7.6180e-02, -8.0597e-03,
#           2.3899e-02,  3.7534e-02, -4.7486e-02, -1.9595e-02,  6.2057e-03,
#           9.6287e-03,  6.1245e-02, -7.9063e-02,  1.1072e-02, -6.1973e-02,
#          -2.3006e-02, -7.0678e-02,  3.4388e-03, -4.9989e-02,  7.8528e-03,
#           2.3379e-02, -5.2529e-02, -2.7042e-02,  1.1806e-01, -9.9260e-03,
#          -6.9694e-02,  5.4264e-02, -5.3585e-03, -6.1666e-02, -7.2194e-02,
#          -8.8087e-02,  2.7978e-02, -2.1680e-02,  1.2009e-01, -2.2796e-02,
#           8.0002e-02,  3.7337e+00,  1.0962e-01,  9.6192e-02,  1.8280e-02,
#          -1.0238e-01]])
# a-c tensor([[ 8.6448e-03, -3.9474e-03, -5.1413e-02,  3.8173e-03, -5.8464e-03,
#          -7.6370e-02,  5.4054e-03, -1.1090e-01,  2.1483e-02,  1.0499e-01,
#          -6.1347e-02, -6.6293e-02, -4.6370e-02, -5.1553e-02, -1.5389e-03,
#           1.3015e-02,  6.9374e-03, -5.4917e-02,  1.2415e-04, -1.4201e-02,
#           6.6559e-02, -9.8306e-02,  3.5825e-02,  9.9551e-02, -7.2817e-02,
#           5.0962e-04, -2.7013e-02,  1.5278e-02,  6.4901e-02, -4.1551e-02,
#           9.5530e-02,  1.8074e-02,  8.7673e-03,  4.0255e-02,  1.6240e-02,
#          -2.9637e-02, -4.5266e-02, -4.5730e-02,  5.9199e-02, -1.3352e-02,
#          -7.7016e-02,  1.0659e-01, -3.0988e-02,  1.6921e-01, -3.6584e-02,
#           7.4340e-03, -4.3619e-03,  5.2861e-02,  1.0070e-02,  3.9996e-02,
#          -3.1555e-02, -1.5054e-02,  3.0227e-02,  2.6834e-01, -2.1043e-02,
#          -1.8061e-02,  5.8065e-02, -7.3098e-02,  1.4451e-02,  2.1776e-02,
#          -1.9969e-02, -3.7853e-02,  2.7628e-02,  3.8344e-02,  1.9679e-03,
#          -2.2142e-02, -3.4104e-01,  2.6387e-02, -3.2709e-02,  1.6885e-02,
#           2.0804e-02,  2.0288e-02, -7.9823e-02, -8.0251e-02, -7.5103e-02,
#           1.8979e-02,  8.8189e-02,  4.7557e-02, -3.2496e-02, -3.0279e-02,
#           2.0869e-02,  4.4708e-03,  9.0598e-02,  1.3140e-02,  7.2015e-04,
#          -2.3975e-02, -3.5098e-02,  1.6598e-02, -3.4854e-02, -5.4032e-02,
#          -5.5395e-02, -4.8377e-02, -1.5801e-02,  2.8608e-03, -8.3004e-02,
#           1.8184e-01, -6.3337e-02,  6.5987e-02, -2.0497e-01,  4.4705e-03,
#           5.6405e-02,  2.4983e-02,  3.5868e-03,  1.7511e-02, -2.0099e-02,
#           5.2210e-04,  2.0004e-02, -9.4073e-02,  9.3173e-02, -7.8177e-02,
#          -4.2405e-02, -1.1330e-02, -1.3272e-02,  5.1424e-02, -8.0985e-02,
#           6.6387e-02,  2.1062e-02, -4.9324e-02, -2.9016e-02, -1.7591e-03,
#           8.3360e-02, -1.6847e-02, -5.4352e-02, -6.9957e-03,  2.5957e-02,
#          -9.5586e-02,  3.6391e-02,  5.4536e-04, -3.0646e-02, -3.5037e-02,
#           1.4391e-02, -1.1671e-02, -4.0813e-02, -5.7616e-02, -9.2525e-01,
#           8.0843e-03,  4.9377e-02, -4.9090e-04,  6.8955e-03, -5.8481e-02,
#           7.7881e-03, -9.7897e-02, -7.3528e-02,  4.7829e-02, -3.5727e-03,
#          -4.6185e-02,  1.4767e-03,  3.2690e-02, -3.5731e-02,  1.4448e-01,
#           5.8453e-02, -5.7074e-02, -3.7771e-02,  7.5713e-02, -3.5085e-02,
#          -3.8096e-03,  2.2285e-01, -1.0287e-01, -9.9290e-02,  8.2613e-03,
#           1.0060e-01,  7.8578e-02, -5.1413e-02, -6.0519e-02, -1.9263e-02,
#          -3.1968e-02, -8.7708e-02, -2.7505e-02,  2.5463e-02,  3.3183e-02,
#           2.9515e-02, -6.1100e-02, -2.4387e-02, -6.0453e-02, -2.1514e-02,
#           7.9666e-02,  7.0936e-02,  3.7607e-02, -2.8790e-02,  3.6532e-02,
#           3.0589e-02, -6.9659e-02,  2.8678e-02,  1.0889e-02,  4.2865e-02,
#           1.5282e-02, -7.1130e-02,  1.2788e-01, -2.0398e-02, -4.1947e-02,
#          -7.2738e-03,  5.7383e-02,  2.6631e-02,  1.8374e-03,  6.9562e-02,
#          -4.5141e-02,  6.3882e-02,  3.5915e-02,  2.1397e-02, -7.1694e-03,
#           2.4561e-02, -5.6510e-03, -1.2361e-02, -1.7914e-02, -2.3183e-02,
#           1.2629e-01, -1.0306e+00,  8.4519e-03, -3.6203e-03, -3.2781e-02,
#          -1.8944e+00,  4.0670e-02, -8.7794e-03, -1.8931e-02, -4.1578e-02,
#          -3.3087e-02,  4.8617e-02,  9.3587e-03,  8.1586e-02, -2.0040e-02,
#           9.6657e-03,  4.8216e-02, -9.0332e-02, -6.5689e-02,  1.5136e-03,
#          -2.6880e-02,  5.8612e-02, -4.2770e-02, -4.9800e-02, -3.1826e-02,
#          -9.4174e-03, -1.0487e-01, -9.2211e-03, -3.8179e-03, -4.5155e-03,
#           4.1056e-02, -6.8343e-02, -7.9895e-03,  1.0886e-01,  3.8307e-02,
#          -6.9912e-02,  8.4381e-02,  3.4398e-02, -6.9356e-02, -5.9582e-02,
#          -3.3002e-02,  4.1769e-02,  1.8745e-02,  1.0160e-01, -6.2229e-02,
#           5.8197e-02,  3.7711e+00,  1.2341e-01,  1.1199e-02, -1.7656e-02,
#          -9.5124e-02]])

# %%
vq_post_emb_a.shape
# Out:
# torch.Size([1, 256, 2303])

# %%
vq_id_a.shape
# Out:
# torch.Size([6, 1, 2303])

# %%
quantized_a[0].shape
# Out:
# torch.Size([1, 256, 2303])

# %%
len(quantized_a)
# Out:
# 3

# %%
spk_embs_a.shape
# Out:
# torch.Size([1, 256])

# %%
import torch
import torch.nn as nn

# Assuming a vocabulary size of 10000 and an embedding dimension of 300
embedding_layer = nn.Embedding(num_embeddings=10000, embedding_dim=300)

# Example input: indices for the words in a sentence
input_ids = torch.tensor([1, 2, 4, 5, 987], dtype=torch.long)

# Lookup the embeddings for these indices
embeddings = embedding_layer(input_ids)

print(embeddings)
# Out:
# tensor([[ 0.3080,  0.9916,  1.0956,  ...,  0.9795,  1.3352, -0.9671],
#         [-0.5183, -0.9238, -1.2977,  ..., -0.3542, -0.5446, -0.2042],
#         [ 1.8300,  0.6884, -0.8165,  ...,  1.6946,  2.4258, -0.3433],
#         [-1.3175, -1.5950,  0.0354,  ...,  0.6821,  0.2656,  1.8985],
#         [-0.1071,  1.4058, -0.8028,  ...,  1.2904, -0.5537, -0.9080]],
#        grad_fn=<EmbeddingBackward0>)
